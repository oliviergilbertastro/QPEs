# %%
from finalRuns_2025 import *
np.int0 = np.int8

# %%
fit_single_object("QPE", 0, bands="r", types=["None"], psf_band="r")
# Out:
# GSN 069
# /home/ogilbert/code/QPEs/finalRuns_2025.py:108: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(fov_image))
# Estimating the background light ... ... ...
# Deblending: 100%|██████████| 14/14 [00:00<00:00, 267.40it/s]
# ---------------DATA PROCESS PARAMETERS-------------
# target_pos: [0 0]
# zero point: 22.5
# ---------------------------------------------------
# FWHM = 0.931"
# The negative PSF values are corrected as 0 values.
# The data_process is ready to go to pass to FittingSpecify!
# The settings for the fitting is done. Ready to pass to FittingProcess.
#   However, please make updates manullay if needed.
# Computing the PSO ...
# /quasar/ogilbert/envs/QPE_galight/lib/python3.13/site-packages/lenstronomy/ImSim/image_linear_solve.py:174: RuntimeWarning: divide by zero encountered in divide
#   A.T, 1 / C_D_response, d, inv_bool=inv_bool
# ...
